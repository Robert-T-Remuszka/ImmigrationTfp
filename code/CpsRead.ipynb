# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # What This Notebook Does
# Simply reads in, appends and saves the IPUMS CPS data extracted in the [CpsPull.ipynb](CpsPull.ipynb) notebook.

# %%
import pandas as pd
import numpy as np
from ipumspy import readers, ddi
from Credentials import MyCredentials
from Functions import *
from pathlib import Path

# Initialize
StateDfCps = pd.DataFrame()

# Create a path object to the data folder
DataDir = Path(Paths['cps'])

# Construct a list of all files in the CPS folder
Files = list(DataDir.glob("*.xml")) 

for f in Files:

    # Get the Data dictionary
    ddi = readers.read_ipums_ddi(f)
    df = readers.read_microdata(ddi, DataDir / ddi.file_description.filename)
    print('\n**********************************************************************\n' +
    f'Saving file {f} corresponding to sample ' + str(df['YEAR'][0]) +
    '\n**********************************************************************\n')
    name = 'Cps' + str(df['YEAR'][0]) + '.dta'
    df.to_stata(DataDir/name, write_index= False)
# Out:
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/cps/cps_00030.xml corresponding to sample 1994
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/cps/cps_00031.xml corresponding to sample 1995
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/cps/cps_00032.xml corresponding to sample 1996
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/cps/cps_00033.xml corresponding to sample 1997
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/cps/cps_00034.xml corresponding to sample 1998
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/cps/cps_00035.xml corresponding to sample 1999
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/cps/cps_00036.xml corresponding to sample 2023
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/cps/cps_00037.xml corresponding to sample 2024
# **********************************************************************
