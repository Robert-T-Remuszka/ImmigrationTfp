# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # What This Notebook Does
# Simply reads in and saves the IPUMS data extracted in the [AcsPull.ipynb](AcsPull.ipynb) notebook.

# %%
import pandas as pd
import numpy as np
from ipumspy import readers, ddi
from Credentials import MyCredentials
from Globals import *
from pathlib import Path

# Initialize
StateDfAcs = pd.DataFrame()

# Create a path object to the data
DataDir = Path(Paths['acs'])

# Construct file list
Files = list(DataDir.glob("*.xml"))

for f in Files:
    
    # Get the Data dictionary
    ddi = readers.read_ipums_ddi(f)
    df = readers.read_microdata(ddi, DataDir / ddi.file_description.filename)
    print('\n**********************************************************************\n' +
    f'Saving file {f} corresponding to sample ' + str(df['YEAR'][0]) +
    '\n**********************************************************************\n')
    name = 'Acs' + str(df['YEAR'][0]) + '.dta'
    df.to_stata(DataDir/name, write_index= False)
# Out:
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00305.xml corresponding to sample 2001
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00306.xml corresponding to sample 2002
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00307.xml corresponding to sample 2003
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00308.xml corresponding to sample 2004
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00309.xml corresponding to sample 2005
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00310.xml corresponding to sample 2006
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00311.xml corresponding to sample 2007
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00312.xml corresponding to sample 2008
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00313.xml corresponding to sample 2009
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00314.xml corresponding to sample 2010
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00315.xml corresponding to sample 2011
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00316.xml corresponding to sample 2012
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00317.xml corresponding to sample 2013
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00318.xml corresponding to sample 2014
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00319.xml corresponding to sample 2015
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00320.xml corresponding to sample 2016
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00321.xml corresponding to sample 2017
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00322.xml corresponding to sample 2018
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00323.xml corresponding to sample 2019
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00324.xml corresponding to sample 2020
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00325.xml corresponding to sample 2021
# **********************************************************************
# /home/r/remuszka/.conda/envs/ImmigrationTfp/lib/python3.12/site-packages/ipumspy/readers.py:70: CitationWarning: Use of data from IPUMS is subject to conditions including that users should cite the data appropriately.
# See the `ipums_conditions` attribute of this codebook for terms of use.
# See the `ipums_citation` attribute of this codebook for the appropriate citation.
#   warnings.warn(
# **********************************************************************
# Saving file ../../data/acs/usa_00326.xml corresponding to sample 2022
# **********************************************************************
